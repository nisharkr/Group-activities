# %% [markdown]
# # Week 7 Activity Group 13

# %%
1. Read the data into python
2. Check for null values
3. Examine the variables ‘Hardness’, ‘Sulfate’, and ‘Organic_carbon’ and
comment on your observations.
4. Carry out correlation analysis on the dataset and find the correlation factor
between
a. ph and Chloramines
b. ph and Conductivity
What do we infer from this correlation value?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading data

# %%
dfData =  pd.read_csv('Week_7_Activity_data.csv')
dfData.head()
# Out:
#           ph    Hardness       Solids  Chloramines     Sulfate  Conductivity  \
# 0   8.316766  214.373394  22018.41744     8.059332  356.886136    363.266516
# 1   9.092223  181.101509  17978.98634     6.546600  310.135738    398.410813
# 2   5.584087  188.313324  28748.68774     7.544869  326.678363    280.467916
# 3  10.223862  248.071735  28749.71654     7.513408  393.663395    283.651634
# 4   8.635849  203.361523  13672.09176     4.563009  303.309771    474.607645
#
#    Organic_carbon  Trihalomethanes  Turbidity
# 0       18.436525       100.341674   4.628771
# 1       11.558279        31.997993   4.075075
# 2        8.399735        54.917862   2.559708
# 3       13.789695        84.603556   2.672989
# 4       12.363817        62.798309   4.401425

# %% [markdown]
# # 2. Check for null values

# %%
dfData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2011 non-null   float64
#  1   Hardness         2011 non-null   float64
#  2   Solids           2011 non-null   float64
#  3   Chloramines      2011 non-null   float64
#  4   Sulfate          2011 non-null   float64
#  5   Conductivity     2011 non-null   float64
#  6   Organic_carbon   2011 non-null   float64
#  7   Trihalomethanes  2011 non-null   float64
#  8   Turbidity        2011 non-null   float64
# dtypes: float64(9)
# memory usage: 141.5 KB

# %% [markdown]
# # There are 2011 rows in the dataset. No null values in the data

# %% [markdown]
# # 3. Examine the variables ‘Hardness’, ‘Sulfate’, and ‘Organic_carbon’ and comment on your observations

# %%
dfData[["ph","Hardness","Sulfate","Organic_carbon"]]
# Out:
#              ph    Hardness     Sulfate  Organic_carbon
# 0      8.316766  214.373394  356.886136       18.436525
# 1      9.092223  181.101509  310.135738       11.558279
# 2      5.584087  188.313324  326.678363        8.399735
# 3     10.223862  248.071735  393.663395       13.789695
# 4      8.635849  203.361523  303.309771       12.363817
# ...         ...         ...         ...             ...
# 2006   8.989900  215.047358  312.931021        9.899115
# 2007   6.702547  207.321086  304.510230       16.217303
# 2008  11.491011   94.812545  258.930600       16.172755
# 2009   6.069616  186.659040  345.700257       12.067620
# 2010   4.668102  193.681736  359.948574       13.894419
#
# [2011 rows x 4 columns]

# %%
dfData1=dfData[['ph',"Hardness","Sulfate","Organic_carbon"]]
corrmatrix1 = dfData1.corr()
plt.subplots(figsize=(15,8))
sns.heatmap(corrmatrix1,vmin=-1,annot=True,linewidths=0.2,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
Except Sulfate and hardness all others positive correlation.
correlations are very small and we can say that there is no relationship among these
Water which contains 120-200 milligrams of hardness is drinkable
Water which contains less than 500 millgrams of sulfate is safe to drink
Water with less than 25 milligrams of Organic Carbon is safe to drink

# %% [markdown]
# # 4. Carry out correlation analysis on the dataset and find the correlation factor
# between
# a. ph and Chloramines
# b. ph and Conductivity
# What do we infer from this correlation value?

# %%
corrmatrix = dfData.corr()
plt.subplots(figsize=(15,8))
sns.heatmap(corrmatrix,vmin=-1,annot=True,linewidths=0.2,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #  a. ph and Chloramines
# # correlation is -0.025. Since the correlation is very small , there is no relationship between the variables.

# %% [markdown]
# # b. ph and Conductivity 0.014 is the correlation which is very small and the relationship is very weak or no relationship
